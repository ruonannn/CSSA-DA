# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 1) Fetch + parse HTML → Documents (handles multiple URLs)
loader = WebBaseLoader(
    web_paths=("https://www.myoffer.cn/article/23512.html",),
    # Optional: control headers, proxies, etc.
    header_template={"User-Agent": "MyResearchBot/1.0 (+contact@email)"},
)
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'https://www.myoffer.cn/article/23512.html', 'title': '\n\t\t\n\t\t澳洲留学签证续签要求：四项续签要求详解 | myOffer®\n\t\t\n\t', 'description': '澳洲留学生如果签证到期但是学业还未完毕，就需要续签，那么澳洲留学签证续签有哪些要求呢？', 'language': 'No language found.'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\t\t\n\t\t澳洲留学签证续签要求：四项续签要求详解 | myOffer®\n\t\t\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n注册\n\n\n\n\n\n\n\n\n\n\n获取验证码\n\n\n\n验证码无法接收？\n\n\n\n注 册\n\n我同意\n注册条款\n已有myoffer账号?立即登录\n\n\n\n\n\n登录\n\n\n\n\n\n\n\n\n\n\n\n登 录\n\n\n短信验证码登录\n\n忘记密码\n\n\n\n\n\n\n\n中国(+86)\n英国(+44)\n马来西亚(+60)\n+61 (澳大利亚)\n+64 (新西兰)\n+852（中国香港）\n+1（加拿大）\n\n\n{{smsLoginParams.errorTips.phone}}\n\n\n{{smsLoginParams.codeText}}\n\n{{smsLoginParams.errorTips.code}}\n\n验证码无法接收？\n\n\n\n登 录\n\n\n账号密码登录\n\n\n\n\n\n\n\n\n\n使用第三方登录\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n还没有myOffer账号？立即注册\n\n\n\n\n\n\n\n\n\n\n\n\n\n这是提示\n\n\n\n\n\n\n\n\t\t\t智能匹配\n\t\t\tTM\n\n\n\t\t\t仅需填写你的留学意向及基本背景资料，myOffer智能匹配系统既可通过REBAT大数据分析技术 (Real-time Evolving Big Data Technology)，运
# ...
