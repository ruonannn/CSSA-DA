# %%
import trafilatura
import json
from langdetect import detect
import hanzidentifier
from urllib.parse import urlparse
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
def extract_TUN_XIAO_EDU_AU_link(max_pages=14):
    links = set()
    for page_number in range(14):
        if page_number == 0:
            url = f"https://au.oliuxue.com/studentnews/?"
        else:
            url = f"https://au.oliuxue.com/studentnews/?page={page_number}"
        print(f'accessing {url}')
        resp = requests.get(url, headers={"User-Agent": "MyBot/1.0"})
        time.sleep(2)
        soup = BeautifulSoup(resp.text, "lxml")

        # Extract all href links
        for a in soup.find_all("a", href=True):
            full_url = urljoin(url, a["href"])  # make relative URLs absolute
            if full_url.startswith('https://au.oliuxue.com/studentnews/'):
                links.add(full_url)
    return links

# %%
def load_web(url):
    print(f'start fetch {url}')
    # Download HTML
    downloaded = trafilatura.fetch_url(url)
    # Extract with metadata
    data_json = trafilatura.extract(
        downloaded,
        output_format="json",   # structured output
        with_metadata=True,     # include title, author, date, etc.
        include_comments=False,
        include_images=False
    )
    if data_json:
        data = json.loads(data_json)

        # return none for 404 page
        if data.get('title') == 'undefined':
            return None
        
        return data
    else:
        return None

# %%
def check_language(text):
    # detect language
    try:
        language = detect(text)
    except:
        return None

    # check chinese script type
    if language.startswith('zh'):
        has_simp = hanzidentifier.is_simplified(text)
        has_trad = hanzidentifier.is_traditional(text)
        
        if has_simp and not has_trad:
            return "simplified-chinese"
        elif has_trad and not has_simp:
            return "traditional-chinese"
        elif has_simp and has_trad:
            return 'mixed-chinese'

    # English language
    elif language.startswith("en"):
        return 'english'
    else:
        return language

# %%
def extract_source(url):
    parsed = urlparse(url)
    domain = parsed.netloc
    return domain

# %%
def parse_json(data, url, id):
    # Parse JSON
    result_json = {
        'id': str(id).zfill(5),
        'question': None,
        'raw_text': data.get('raw_text'),
        'text': data.get('text'),
        'source': extract_source(url),
        'title': data.get('title'),
        'author': data.get('author'),
        'post_date': data.get('date'),
        'language': check_language(data.get('text')),
        'created_at': data.get('filedate'),
        'excerpt': data.get('excerpt'),
        'tags': [data.get('tags')],
        'link': url
    }
    return result_json

# %%
def main():
    id = 13406
    json_list = []
    urls = extract_TUN_XIAO_EDU_AU_link()
    print(f'url collection succeed, collectoed {len(urls)} urls')
    seen = set()
    for url in urls:
        if url in seen:
            continue
        seen.add(url)
        data_json = load_web(url)
        time.sleep(2)
        if not data_json:
            print('No result fetched\n')
            continue

        id += 1
        result_json = parse_json(data_json, url, id)
        json_list.append(result_json)
        print('Successfully fetched\n')
    
    print('fetch finished')
    with open("../data/YUN_XIAO_EDU_AU.json", "w", encoding="utf-8") as f:
        json.dump(json_list, f, ensure_ascii=False, indent=2)

# %%
if __name__ == '__main__':
    main()
# Out:
# accessing https://au.oliuxue.com/studentnews/?
# accessing https://au.oliuxue.com/studentnews/?page=1
# accessing https://au.oliuxue.com/studentnews/?page=2
# accessing https://au.oliuxue.com/studentnews/?page=3
# accessing https://au.oliuxue.com/studentnews/?page=4
# accessing https://au.oliuxue.com/studentnews/?page=5
# accessing https://au.oliuxue.com/studentnews/?page=6
# accessing https://au.oliuxue.com/studentnews/?page=7
# accessing https://au.oliuxue.com/studentnews/?page=8
# accessing https://au.oliuxue.com/studentnews/?page=9
# accessing https://au.oliuxue.com/studentnews/?page=10
# accessing https://au.oliuxue.com/studentnews/?page=11
# accessing https://au.oliuxue.com/studentnews/?page=12
# accessing https://au.oliuxue.com/studentnews/?page=13
# url collection succeed, collectoed 233 urls
# start fetch https://au.oliuxue.com/studentnews/1995.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3999.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4658.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2518.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=13
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1382.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=1
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1883.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1760.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1110.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1609.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1059.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4892.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/579.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2701.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1486.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2506.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2354.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1677.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1635.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2299.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5018.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4493.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2165.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1363.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1666.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1289.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3909.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3927.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4605.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2257.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1553.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/980.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2389.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4602.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/591.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2448.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1338.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1625.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=9
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2544.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2164.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2063.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1201.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4016.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4608.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4629.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2371.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1567.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4630.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4626.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=12
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1376.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4473.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2151.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/774.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1954.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=7
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1678.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5024.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2499.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1622.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1064.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2584.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3633.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/913.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/720.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/674.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4844.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4303.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1318.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4872.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2220.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4435.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2672.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2096.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2215.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1568.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1198.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1806.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1212.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1113.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4711.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4598.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3430.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3401.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2583.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1994.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/991.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1508.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4623.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4217.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2521.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4279.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/673.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4818.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1095.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1868.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1861.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3419.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1422.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2886.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2486.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4000.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4719.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4624.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1671.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1529.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2280.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1563.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2369.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4059.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1232.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2586.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3482.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2594.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1485.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=5
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4865.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2218.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2219.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1449.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1069.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2310.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4625.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=2
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1593.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/672.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1423.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2605.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1942.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5023.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=4
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4573.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4790.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1061.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2233.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5134.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2309.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2390.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5017.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3483.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/675.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1545.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=10
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2872.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5190.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1714.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=6
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/975.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3640.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3379.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2410.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2318.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2276.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4721.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2728.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1820.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2595.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1020.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1372.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3070.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=3
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4651.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2590.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3645.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1595.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/677.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1309.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4866.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1712.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1160.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4501.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1718.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1830.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3580.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2317.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4597.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3481.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2667.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1748.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2604.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2500.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=11
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1396.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1194.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1225.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/676.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4426.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4085.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3422.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5038.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4656.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1732.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1505.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4627.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5019.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2945.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4607.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5056.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4684.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4772.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/?page=8
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1057.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1434.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/3421.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1739.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2199.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2677.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2243.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2380.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2891.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2206.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4603.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1427.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1127.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2441.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/578.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1634.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5208.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1541.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2703.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/4966.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2278.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2592.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5064.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/719.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2014.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/2227.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/1893.html
# Successfully fetched
#
# start fetch https://au.oliuxue.com/studentnews/5201.html
# Successfully fetched
#
# fetch finished
